# %%
import pandas as pd
import sqlalchemy as sa
import psycopg2 as ps
from sqlalchemy import create_engine

# %%
# %load_ext sql
# %sql postgresql://postgres:lingga28@localhost:2828/datacamp
conn = create_engine('postgresql://postgres:lingga28@localhost/datacamp')

# %% [markdown]
# # 1. Text data types
# ### Exercises
# You learned about some of the common data types that you'll work within PostgreSQL, some characteristics of these types, and how to determine the data type of a column in an existing table. Think back to the video and answer the following question:
#
# Which of the following is not a valid text data type in PostgreSQL?
#
# ### Answer the question
# ### Possible Answers
#
# - A. TEXT
# - B. STRING
# - C. CHAR
# - C. VARCHAR
#
# Answer: B

# %% [markdown]
# # 2. Getting information about your database
# ### Exercises
# As we saw in the video, PostgreSQL has a system database called INFORMATION_SCHEMA that allows us to extract information about objects, including tables, in our database.
#
# In this exercise we will look at how to query the tables table of the INFORMATION_SCHEMA database to discover information about tables in the DVD Rentals database including the name, type, schema, and catalog of all tables and views and then how to use the results to get additional information about columns in our tables.

# %% [markdown]
# ### task 1
# ### Instruction
# Select all columns from the INFORMATION_SCHEMA.TABLES system database. Limit results that have a public table_schema.

# %%
# %%sql
#
#  -- Select all columns from the TABLES system database
#  SELECT *
#  FROM INFORMATION_SCHEMA.TABLES
#  -- Filter by schema
#  WHERE table_schema = 'public';
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# 38 rows affected.
# [('datacamp', 'public', 'economies', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'countries', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'cities', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'teams_spain', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'matches_italy', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'teams_italy', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'languages', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'currencies', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'populations', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'economies2019', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'economies2015', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'teams_germany', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'matches', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'matches_2013_2014', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'books', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'country', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'league', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'match', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'matches_germany', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'library_authors', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('datacamp', 'public', 'team', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'matches_spain', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'summer_medals', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'actor', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'address', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'category', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'city', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'countryy', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'customer', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'film_actor', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'film_category', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'inventory', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'language', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'payment', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'rental', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'staff', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'store', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('datacamp', 'public', 'film', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %% [markdown]
# ### task 2
# ### Instruction
# Select all columns from the INFORMATION_SCHEMA.COLUMNS system database. Limit by table_name to actor

# %%
# %%sql
#
#  -- Select all columns from the COLUMNS system database
#  SELECT *
#  FROM INFORMATION_SCHEMA.COLUMNS
#  WHERE table_name = 'actor';
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# 8 rows affected.
# [('datacamp', 'dvdrentals', 'actor', 'actor_id', 1, None, 'YES', 'smallint', None, None, 16, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'datacamp', 'pg_catalog', 'int2', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('datacamp', 'dvdrentals', 'actor', 'first_name', 2, None, 'YES', 'character varying', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'datacamp', 'pg_catalog', 'varchar', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('datacamp', 'dvdrentals', 'actor', 'last_name', 3, None, 'YES', 'character varying', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'datacamp', 'pg_catalog', 'varchar', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('datacamp', 'dvdrentals', 'actor', 'last_update', 4, None, 'YES', 'timestamp without time zone', None, None, None, None, None, 6, None, None, None, None, None, None, None, None, None, None, None, 'datacamp', 'pg_catalog', 'timestamp', None, None, None, None, '4', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('datacamp', 'public', 'actor', 'actor_id', 1, None, 'YES', 'smallint', None, None, 16, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'datacamp', 'pg_catalog', 'int2', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('datacamp', 'public', 'actor', 'first_name', 2, None, 'YES', 'character varying', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'datacamp', 'pg_catalog', 'varchar', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('datacamp', 'public', 'actor', 'last_name', 3, None, 'YES', 'character varying', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'datacamp', 'pg_catalog', 'varchar', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('datacamp', 'public', 'actor', 'last_update', 4, None, 'YES', 'timestamp without time zone', None, None, None, None, None, 6, None, None, None, None, None, None, None, None, None, None, None, 'datacamp', 'pg_catalog', 'timestamp', None, None, None, None, '4', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES')]

# %% [markdown]
# # 3. Determining data types
# ### Exercises
# The columns table of the INFORMATION_SCHEMA database also allows us to extract information about the data types of columns in a table. We can extract information like the character or string length of a CHAR or VARCHAR column or the precision of a DECIMAL or NUMERIC floating point type.
#
# Using the techniques you learned in the lesson, let's explore the customer table of our DVD Rental database.
#
# ### Instructions
# - Select the column name and data type from the INFORMATION_SCHEMA.COLUMNS system database.
# - Limit results to only include the customer table.

# %%
# %%sql
#
# -- Get the column name and data type
# SELECT
#  	column_name,
#     data_type
# -- From the system database information schema
# FROM INFORMATION_SCHEMA.COLUMNS
# -- For the customer table
# WHERE table_name = 'customer';
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# 20 rows affected.
# [('customer_id', 'smallint'),
#  ('store_id', 'smallint'),
#  ('first_name', 'character varying'),
#  ('last_name', 'character varying'),
#  ('email', 'character varying'),
#  ('address_id', 'smallint'),
#  ('activebool', 'boolean'),
#  ('create_date', 'date'),
#  ('last_update', 'timestamp without time zone'),
#  ('active', 'integer'),
#  ('customer_id', 'smallint'),
#  ('store_id', 'smallint'),
#  ('first_name', 'character varying'),
#  ('last_name', 'character varying'),
#  ('email', 'character varying'),
#  ('address_id', 'smallint'),
#  ('activebool', 'boolean'),
#  ('create_date', 'date'),
#  ('last_update', 'timestamp without time zone'),
#  ('active', 'integer')]

# %% [markdown]
# # 4. Properties of date and time data types
# ### Exercises
# Which of the following is NOT correct?
#
# ### Answer the question
# ### Possible Answers
#
# - A. TIMESTAMP data types contain both date and time values.
# - B. DATE data types use an yyyy-mm-dd format.
# - C. INTERVAL types are representations of periods of time.
# - D. TIME data types are stored with a timezone by default.
#
# Answer: D

# %% [markdown]
# # 5. Interval data types
# ### Exercises
# INTERVAL data types provide you with a very useful tool for performing arithmetic on date and time data types. For example, let's say our rental policy requires a DVD to be returned within 3 days. We can calculate the expected_return_date for a given DVD rental by adding an INTERVAL of 3 days to the rental_date from the rental table. We can then compare this result to the actual return_date to determine if the DVD was returned late.
#
# Let's try this example in the exercise.
#
# ### Instructions
# - Select the rental date and return date from the rental table.
# - Add an INTERVAL of 3 days to the rental_date to calculate the expected return date`.

# %%
# %%sql
#
# SELECT
#  	-- Select the rental and return dates
# 	rental_date,
# 	return_date,
#  	-- Calculate the expected_return_date
# 	rental_date + INTERVAL '3 days' AS expected_return_date
# FROM rental
# LIMIT 10; --just an addition, so that the table is not elongated
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# 10 rows affected.
# [(datetime.datetime(2005, 5, 24, 22, 53, 30), datetime.datetime(2005, 5, 26, 22, 4, 30), datetime.datetime(2005, 5, 27, 22, 53, 30)),
#  (datetime.datetime(2005, 5, 24, 22, 54, 33), datetime.datetime(2005, 5, 28, 19, 40, 33), datetime.datetime(2005, 5, 27, 22, 54, 33)),
#  (datetime.datetime(2005, 5, 24, 23, 3, 39), datetime.datetime(2005, 6, 1, 22, 12, 39), datetime.datetime(2005, 5, 27, 23, 3, 39)),
#  (datetime.datetime(2005, 5, 24, 23, 4, 41), datetime.datetime(2005, 6, 3, 1, 43, 41), datetime.datetime(2005, 5, 27, 23, 4, 41)),
#  (datetime.datetime(2005, 5, 24, 23, 5, 21), datetime.datetime(2005, 6, 2, 4, 33, 21), datetime.datetime(2005, 5, 27, 23, 5, 21)),
#  (datetime.datetime(2005, 5, 24, 23, 8, 7), datetime.datetime(2005, 5, 27, 1, 32, 7), datetime.datetime(2005, 5, 27, 23, 8, 7)),
#  (datetime.datetime(2005, 5, 24, 23, 11, 53), datetime.datetime(2005, 5, 29, 20, 34, 53), datetime.datetime(2005, 5, 27, 23, 11, 53)),
#  (datetime.datetime(2005, 5, 24, 23, 31, 46), datetime.datetime(2005, 5, 27, 23, 33, 46), datetime.datetime(2005, 5, 27, 23, 31, 46)),
#  (datetime.datetime(2005, 5, 25, 0, 0, 40), datetime.datetime(2005, 5, 28, 0, 22, 40), datetime.datetime(2005, 5, 28, 0, 0, 40)),
#  (datetime.datetime(2005, 5, 25, 0, 2, 21), datetime.datetime(2005, 5, 31, 22, 44, 21), datetime.datetime(2005, 5, 28, 0, 2, 21))]

# %% [markdown]
# # 6. Accessing data in an ARRAY
# ### Exercises
# In our DVD Rentals database, the film table contains an ARRAY for special_features which has a type of TEXT[]. Much like any ARRAY data type in PostgreSQL, a TEXT[] array can store an array of TEXT values. This comes in handy when you want to store things like phone numbers or email addresses as we saw in the lesson.
#
# Let's take a look at the special_features column and also practice accessing data in the ARRAY.

# %% [markdown]
# ### task 1
# #### Instruction
# Select the title and special features from the film table and compare the results between the two columns.

# %%
# %%sql
#
# -- Select the title and special features column
# SELECT
#   title,
#   special_features
# FROM film
# LIMIT 3; --just an addition, so that the table is not elongated
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# 3 rows affected.
# [('BEACH HEARTBREAKERS', ['Deleted Scenes', 'Behind the Scenes']),
#  ('BEAST HUNCHBACK', ['Deleted Scenes', 'Behind the Scenes']),
#  ('BEDAZZLED MARRIED', ['Trailers', 'Deleted Scenes', 'Behind the Scenes'])]

# %% [markdown]
# ### task 2
# ### Instruction
# Select all films that have a special feature Trailers by filtering on the first index of the special_features ARRAY.

# %%
# %%sql
#
# -- Select the title and special features column
# SELECT
#   title,
#   special_features
# FROM film
# -- Use the array index of the special_features column
# WHERE special_features[1] = 'Trailers'
# LIMIT 3; --just an addition, so that the table is not elongated
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# 3 rows affected.
# [('BEDAZZLED MARRIED', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('BEHAVIOR RUNAWAY', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('BLUES INSTINCT', ['Trailers', 'Deleted Scenes', 'Behind the Scenes'])]

# %% [markdown]
# ### task 3
# ### Instruction
# Now let's select all films that have Deleted Scenes in the second index of the special_features ARRAY.

# %%
# %%sql
#
# -- Select the title and special features column
# SELECT
#   title,
#   special_features
# FROM film
# -- Use the array index of the special_features column
# WHERE special_features[2] = 'Deleted Scenes'
# LIMIT 3; --just an addition, so that the table is not elongated
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# 3 rows affected.
# [('BEDAZZLED MARRIED', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('BEHAVIOR RUNAWAY', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('BETRAYED REAR', ['Commentaries', 'Deleted Scenes', 'Behind the Scenes'])]

# %% [markdown]
# # 7. Searching an ARRAY with ANY
# ### Exercises
# As we saw in the video, PostgreSQL also provides the ability to filter results by searching for values in an ARRAY. The ANY function allows you to search for a value in any index position of an ARRAY. Here's an example.
#
# WHERE 'search text' = ANY(array_name)
# When using the ANY function, the value you are filtering on appears on the left side of the equation with the name of the ARRAY column as the parameter in the ANY function.
#
# ### Instruction
# Match 'Trailers' in any index of the special_features ARRAY regardless of position.

# %%
# %%sql
#
# SELECT
#   title,
#   special_features
# FROM film
# -- Modify the query to use the ANY function
# WHERE 'Trailers' = ANY (special_features)
# LIMIT 10; --just an addition, so that the table is not elongated
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# 10 rows affected.
# [('BEDAZZLED MARRIED', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('BEHAVIOR RUNAWAY', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('BLUES INSTINCT', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('BUBBLE GROSSE', ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes']),
#  ('CAMELOT VACATION', ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes']),
#  ('CASABLANCA SUPER', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('CHARADE DUFFEL', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('CHICKEN HELLFIGHTERS', ['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes']),
#  ('CIRCUS YOUTH', ['Trailers', 'Deleted Scenes', 'Behind the Scenes']),
#  ('CLEOPATRA DEVIL', ['Trailers', 'Deleted Scenes', 'Behind the Scenes'])]

# %% [markdown]
# # 8. Searching an ARRAY with @>
# ### Exercises
# The contains operator @> operator is alternative syntax to the ANY function and matches data in an ARRAY using the following syntax.
#
# WHERE array_name @> ARRAY['search text'] :: type[]
# So let's practice using this operator in the exercise.
#
# ### Instruction
# Use the contains operator to match the text Deleted Scenes in the special_features column.

# %%
# %%sql
#
# SELECT
#   title,
#   special_features
# FROM film
# -- Filter where special_features contains 'Deleted Scenes'
# WHERE special_features @> ARRAY['Deleted Scenes']
# LIMIT 10; --just an addition, so that the table is not elongated
# Out:
#  * postgresql://postgres:***@localhost:2828/datacamp
# (psycopg2.errors.UndefinedFunction) operator does not exist: character varying[] @> text[]
# LINE 6: WHERE special_features @> ARRAY['Deleted Scenes']
#                                ^
# HINT:  No operator matches the given name and argument types. You might need to add explicit type casts.
#
# [SQL: SELECT
#   title,
#   special_features
# FROM film
# -- Filter where special_features contains 'Deleted Scenes'
# WHERE special_features @> ARRAY['Deleted Scenes']
# LIMIT 10; --just an addition, so that the table is not elongated]
# (Background on this error at: https://sqlalche.me/e/14/f405)
