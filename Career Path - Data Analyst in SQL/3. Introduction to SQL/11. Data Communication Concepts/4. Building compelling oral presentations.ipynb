# %% [markdown]
# # 1. Is this the plan?
# ### Exercisess
# You need to present your findings on software development sector salaries for San Francisco employees and the predictive model you used, which you worked on in Chapter 2, to the executive team.
#
# You open your computer and start drafting slides. But then, you recall the course you took on communicating with data. You feel that you are missing something. So you write down the facts you remember to build a compelling oral presentation.
#
# Can you identify which of the following statements is correct?
#
# ### Instruction
# Correctly classify the statements as either true or false.
#
# ### Drag the items into the correct bucket:
# - List at least five key messages that you want to convey to the executive team. This approach helps you determine the structure of your presentation
# - Plan to conclude your presentation by listing all the details and limitations of your work. Open for questions concerning improvements of your work
# - The plan for delivering a presentation for five members of the executive team or the whole IT staff would be exactly the same.
# - Plan to explain how the average private-sector salary has increased in the last five years because it helps you catch the audience's attention.
# - For the executive team, you shuould deliver a persuasive presentation to convince them to have salary ranges that are equal to the industry average.
#
# True:
# - Plan to explain how the average private-sector salary has increased in the last five years because it helps you catch the audience's attention.
# - For the executive team, you shuould deliver a persuasive presentation to convince them to have salary ranges that are equal to the industry average.
#
# False:
# - List at least five key messages that you want to convey to the executive team. This approach helps you determine the structure of your presentation
# - Plan to conclude your presentation by listing all the details and limitations of your work. Open for questions concerning improvements of your work
# - The plan for delivering a presentation for five members of the executive team or the whole IT staff would be exactly the same.

# %% [markdown]
# # 2. An effective plan!
# ### Exercise
# Well done! You identified which statements were correct. Now, you know how to plan your slides on salaries for San Francisco employees. It's time to determine which sections you will include in your presentation.
#
# Can you put in order the topics for the sections of your oral presentation?
#
# ### Instruction
# Order the presentation sections so that the first section should be on top and the last at the bottom.
#
# ### Drag the items below into order:
# - Employees will be leaving due to higher salaries on other companies
# - Analysis of software development salaries from different companies
# - Increase in private sector salaries over the last 5 years
# - Company should offer competitive salary ranges to retain talented staff
# - Forecast salaries for the software sector the next 5 years
#
# ### Answers:
# - Increase in private sector salaries over the last 5 years
# - Analysis of software development salaries from different companies
# - Forecast salaries for the software sector the next 5 years
# - Employees will be leaving due to higher salaries on other companies
# - Company should offer competitive salary ranges to retain talented staff

# %% [markdown]
# # 3. A color building
# ### Exercise
# You have planned the presentation for your findings on software development sector salaries for San Francisco employees. Now, it's time to build the slides. After putting your slide deck together, you ask your coworker to give you feedback. She makes comments on the different slides.
#
# You start by reviewing the following graph slide.
#
# ![](visual_slide.png)
#
# One of the comments she wrote about the slide is not correct. Can you select which one it is?
#
# Answer the question
# 50XP
# Possible Answers
# - A. The headline looks stylish. Even though the spacing between the letters is small, the font adds originality to the slide.
# - B. The amount of graphs displayed is adequate. The two full-size graphs can be properly seen and compared.
# - C. It's a good idea using the red square to emphasize one of the graph. It will make the audience focus on what graph you are explaining.
#
# Answer: A

# %% [markdown]
# # 4. Too much text
# ### Exercise
# Your coworker also gives you feedback on slides that only have text. She feels like the slide can be improved a lot. She gives you some options on how you can improve the slide.
#
# ![](text_slide.png)
#
# One of the following statement is not correct. Can you select which one is it?
#
# ### Answer the question
# ### Possible Answers
# - A. Instead of writing all the text in paragraphs, convert each concise main idea to bullet points.
# - B. The headline is well formated using big letters. Also, it is specific and concise.
# - C. Highlight the keywords in the text using red, green, yellow, blue, and magenta. Using several colors will help catch the audience's attention.
# - D. It would be a good idea to break the slide into two slides. In the first one, put the second paragraph in gray. Reveal the text in the second slide.
#
# Answer: C

# %% [markdown]
# # 5. The right building
# ### Exercise
# Well done building a text slide! Now, you need to review the rest of the comments from your coworker. She left you the feedback in two stacks of notes: one stack for best practices and one stack for what you should avoid. However, the stacks fell during your lunch break and are all mixed up.
#
# Can you classify which of the following comments are best practice in building a presentation, and which ones should be avoided?
#
# ### Instruction
# Correctly classify the comments as either best practices or practices to avoid.
#
# ### Drag the items into the correct bucket:
# - You were given twenty minutes to talk. The presentation has fifteen slides.
# - Most of the slides have a light blue background. The words appear in grey font.
# - In this paragraph, the keywords salary, market and retention are in bold.
# - Include one slide to display that the company is behind market salaries an dalso, that 40% of the software companies are located in San Fransisco.
# - Include two slides that shows that the software market has been growing in the last years to support your message that the salaries are increasing
#
# Best practice:
# - You were given twenty minutes to talk. The presentation has fifteen slides.
# - In this paragraph, the keywords salary, market and retention are in bold.
# - Include two slides that shows that the software market has been growing in the last years to support your message that the salaries are increasing
#
# Avoid:
# - Most of the slides have a light blue background. The words appear in grey font.
# - Include one slide to display that the company is behind market salaries an dalso, that 40% of the software companies are located in San Fransisco.

# %% [markdown]
# # 6. Put it into practice
# ### Exercise
# Excellent job creating those slides for the project on software development sector salaries for San Francisco employees!
#
# Now that you have your slide deck ready, it's time to deliver your presentation. Your project manager sends you an email. She asks you if you can have the meeting at the end of the afternoon. You are unsure because you need to practice. So you ask for some time for rehearsal. To convince your manager, you make a list of the advantages of practicing and rehearsing a presentation.
#
# Can you decide which example you wrote is correct and which one is incorrect?
#
# ### Instruction
# Correctly classify the statements as either true or false.
#
# ### Drag the items into the correct bucket:
# - It's a good idea to prepare answers to anticipate the CEO and the board of directors' questions, and to practice responding to tgen out loud
# - To become familiar with your content, you should write a script and repeat it many times word by word while rehearsing.
# - Rehearsing several times helps you discover if you use expressions such as 'actually', 'like', 'um', 'I mean', 'you know', 'kind of', etc.
# - It's important that you rehearse many times so when you give the presentation you are confident with the content
# - You should rehearse your presentation standing up and projecting the slides, and use this rehearsal to figure out what to say in each slide
# - Because each slide conveys a single message, there is no need to verbally transition from one slide to the other
#
# True:
# - It's a good idea to prepare answers to anticipate the CEO and the board of directors' questions, and to practice responding to tgen out loud
# - Rehearsing several times helps you discover if you use expressions such as 'actually', 'like', 'um', 'I mean', 'you know', 'kind of', etc.
# - It's important that you rehearse many times so when you give the presentation you are confident with the content
#
# False:
# - To become familiar with your content, you should write a script and repeat it many times word by word while rehearsing.
# - You should rehearse your presentation standing up and projecting the slides, and use this rehearsal to figure out what to say in each slide
# - Because each slide conveys a single message, there is no need to verbally transition from one slide to the other

# %% [markdown]
# # 7. Best practice
# ### Exercise
# Your rehearsal went very well! You are ready to present to the stakeholders.
#
# However, you feel nervous. You know this is completely normal but you don't want to look like you are unsure of your content. You take three big breaths and remember your training. There are some key points that will help you deliver the presentation effectively.
#
# Can you identify which of this statements is a suitable point to consider, and which one is not?
#
# ### Instruction
# Correctly classify the following examples as either a true or false.
#
# ### Drag the Items into the correct bucket:
# - You should emphasize well-known concepts by saying 'As you all know, this alghoritm has good accuracy for forecasting problems.'
# - Your central message should be repeated and linked to your findings throughout your slide deck
# - If your audience is engaged with your presentation, you can explain your content in detail, even if it takes longer than expected.
# - If you realize you are too nervous, you should avoid making eye contact with the audience. They will be unconvinced of your content.
# - It's a good idea to pause for a few seconds after you reveal the main finding, so your audience has time to process what you have just explained
# - Give your presentation with the enthusiasm. The audience picks up on your feelings. If you are confident, they will be convinced with your content
#
# True:
# - Your central message should be repeated and linked to your findings throughout your slide deck
# - It's a good idea to pause for a few seconds after you reveal the main finding, so your audience has time to process what you have just explained
# - Give your presentation with the enthusiasm. The audience picks up on your feelings. If you are confident, they will be convinced with your content
#
# False:
# - You should emphasize well-known concepts by saying 'As you all know, this alghoritm has good accuracy for forecasting problems.'
# - If your audience is engaged with your presentation, you can explain your content in detail, even if it takes longer than expected.
# - If you realize you are too nervous, you should avoid making eye contact with the audience. They will be unconvinced of your content.

# %% [markdown]
# # 8. The true mistake
# ### Exercise
# Your coworker asks you to help him practice for his presentation. He wants your feedback so he can be prepared to deliver an important project to the company's CEO.
#
# He gives you a list of best practices he should observe during his speech. But you notice that some of them are not correct.
#
# Can you identify which statements are wrong?
#
# ### Instruction
# Correctly classify the statements as either true or false.
#
# ### Drag the Items into the correct bucket:
# - The speaker is at the center of the preentation and acts as a guide for the audience
# - To catch the audience's attention, start by stating the key assumpations in a low voice, and reveal all the findings at the end speaking loud.
# - Deliver the presentation in 15 minutes and afterwards, open up for 10 minutes of questions.
# - A common mistake is to skip the purpose of the presentation and dive directly into the findings.
# - The audience should be engaged by speaking fast without pauses from the beginning of the presentation
#
# True:
# - The speaker is at the center of the preentation and acts as a guide for the audience
# - Deliver the presentation in 15 minutes and afterwards, open up for 10 minutes of questions.
# - A common mistake is to skip the purpose of the presentation and dive directly into the findings.
#
# False:
# - To catch the audience's attention, start by stating the key assumpations in a low voice, and reveal all the findings at the end speaking loud.
# - The audience should be engaged by speaking fast without pauses from the beginning of the presentation

# %% [markdown]
# # 9. Do's and don'ts
# ### Exercise
# It's the day before the presentation for your project on customer churn. Your team lead arrives and tells you that the CEO will be there to listen to your results. You start getting nervous.
#
# You have planned your presentation. You built the slides focusing on a non-tech audience. You have practiced and rehearsed with some colleagues. But you really want to avoid making any common mistakes during your talk. So you decide to practice one more time.
#
# To achieve your goal, you need to remember best practices so you can implement them. Also, you should make a list of common errors so you can avoid them.
#
# ### Instruction
# Correctly classify the examples as either a best practice or a common mistake.
#
# ### Drag the Items into the correct bucket:
# - Explaining at the end that 20% of customers left with an equal gender balance, and that the monthly charge is a good predictor of churn.
# - Avoiding moving your hands or pointing to the screen when showing that the company should create a promotional campaign to retain its customers.
# - Showing a boxplot of the amount of months churning and non-churning customers subscribed without reiterating that tenure affects customer churn.
# - Omitting that you assume that it costs 15% more to attract a customer than to retain an existing one, so the presentation is not long.
# - Asking your audience if they believe that the type of phone service a client has is an important factor impacting the customer churn rate.
# - Speak slowly when showing the importance of Fiber Optic for predicting churn but faster when explaining the urgency to change the Streaming TV plan.
#
# Best practices:
# - Asking your audience if they believe that the type of phone service a client has is an important factor impacting the customer churn rate.
# - Speak slowly when showing the importance of Fiber Optic for predicting churn but faster when explaining the urgency to change the Streaming TV plan.
#
# Common mistakes
# - Explaining at the end that 20% of customers left with an equal gender balance, and that the monthly charge is a good predictor of churn.
# - Avoiding moving your hands or pointing to the screen when showing that the company should create a promotional campaign to retain its customers.
# - Showing a boxplot of the amount of months churning and non-churning customers subscribed without reiterating that tenure affects customer churn.
# - Omitting that you assume that it costs 15% more to attract a customer than to retain an existing one, so the presentation is not long.
