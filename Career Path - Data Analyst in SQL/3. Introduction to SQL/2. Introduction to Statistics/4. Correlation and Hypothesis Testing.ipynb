# %% [markdown]
# # 1. Sunshine and sleep
# ### WExercise
# Say you are planning to perform two hypothesis tests:
#
# One to establish whether a relationship exists between the number of hours of sunshine per day in London and how many hours per night the residents sleep, and
# Another to check if exercise is related to blood pressure in elderly men.
# Some statements have been provided. Your task is to correctly classify each statement as describing a null hypothesis or an alternative hypotheses for these two tests.
#
# ### Instruction
# Classify each statement as either a null hypothesis or an alternative hypothesis.
#
# ### Drag the items into the correct bucket:
# - The amount of exercise performed each week has no effect on blood pressure in elderly men.
# - A relationship exists between the number of hours of sunshine received in London per day and the number of hours its residents sleep.
# - More exercise is associated with lower blood pressure levels in elderly men.
# - No difference exists between the number of hours London residents sleep and the amount of sunshine received per day.
#
# ### Answers:
# Null hypothesis:
# - The amount of exercise performed each week has no effect on blood pressure in elderly men.
# - No difference exists between the number of hours London residents sleep and the amount of sunshine received per day.
#
# Alternative hypothesis:
# - A relationship exists between the number of hours of sunshine received in London per day and the number of hours its residents sleep.
# - More exercise is associated with lower blood pressure levels in elderly men.

# %% [markdown]
# # 2. The hypothesis testing workflow
# ### Exercise
# Hypothesis testing requires a sequence of tasks to be completed in a particular order.
#
# You are preparing to perform a hypothesis test on whether a difference exists between the frequency of colds in 18-30 year olds who are meat-eaters and vegetarians.
#
# Your task is to reorder the actions to accurately represent a typical hypothesis testing workflow.
#
# ### Instruction
# Order the sequence of events to accurately represent a general hypothesis testing workflow.
#
# ### Drag the items below into order:
# - **Collect the data**: diet status and number of colds in the last six months
# - **Perform statistical tests on the sample data**: difference in mean number if colds between the two populations
# - **Define the alternative hypothesis**: young adults who eat meat experience more colds
# - **Define the population**: adults aged 18 to 30 who eat meat or are vegetarian
# - **Define the null hypothesis**: there is no difference in the frequency of colds among meat-eaters and vegetarians
# - **Draw conclusions about the population**: are the frequency of colds different for young adults who consume meat
#
# ### Answers:
# - **Define the population**: adults aged 18 to 30 who eat meat or are vegetarian
# - **Define the null hypothesis**: there is no difference in the frequency of colds among meat-eaters and vegetarians
# - **Define the alternative hypothesis**: young adults who eat meat experience more colds
# - **Collect the data**: diet status and number of colds in the last six months
# - **Perform statistical tests on the sample data**: difference in mean number if colds between the two populations
# - **Draw conclusions about the population**: are the frequency of colds different for young adults who consume meat

# %% [markdown]
# # 3. Independent and dependent variables
# ### Exercise
# You are planning a hypothesis test to see if there is a difference in the amount of sunshine a city receives per year and how many hours are worked annually. Your alternative hypothesis is that more sunshine is associated with fewer hours worked.
#
# You monitor the amount of sunshine in three cities for one hundred days, and collect data on the number of hours worked from 30 people in each city.
#
# Your task is to decide what would be considered the dependent variable in this hypothesis test.
#
# ### Answer the question
# ### Possible Answers
# - A. City
# - B. Hours worked annually
# - C. Amount of sunshine
#
# Answer: B

# %% [markdown]
# # 4. Recognizing controlled trials
# ### Exercise
# The video highlighted the benefits of controlled trials, particularly using randomization and double-blinding. However, there are lots of ways to perform experiments and sometimes a controlled trial might not be appropriate or even feasible.
#
# In this exercise, you'll need to classify each scenario based on whether it describes a controlled trial or another type of experiment.
#
# ### Instruction
# Place each scenario into the bucket describing the correct type of experiment.
#
# ### Drag the items into the correct bucket:
# - Performing crash safety tests on current and upgraded versions of a car and analyzing how much damage is sustained by each version
# - Displaying one of two versions of a company website to visitors and monitoring time spent on the site for each version
# - Investigating what proportion of people aged 20 to 35 like strawberry ice cream
# - Randomly assigning people to a specific diet or to continue eating their normal diet and analyzing differences in blood sugar levels
# - Collecting survey data from 500 people to find out their smoking status and whether they have had cancer
# - Tracking the diets of 1000 people over 10 years and monitoring how many of the group develop heart disease
#
# ### Answers:
# Controlled Trial:
# - Performing crash safety tests on current and upgraded versions of a car and analyzing how much damage is sustained by each version
# - Displaying one of two versions of a company website to visitors and monitoring time spent on the site for each version
# - Randomly assigning people to a specific diet or to continue eating their normal diet and analyzing differences in blood sugar levels
#
# Other type of experiment:
# - Investigating what proportion of people aged 20 to 35 like strawberry ice cream
# - Collecting survey data from 500 people to find out their smoking status and whether they have had cancer
# - Tracking the diets of 1000 people over 10 years and monitoring how many of the group develop heart disease

# %% [markdown]
# # 5. Why use randomization?
# ### Exercise
# Controlled trials allow participants to be split into either a control group or a treatment group.
#
# Randomization is incredibly beneficial as part of this process, but can you recall why?
#
# Some reasons are listed below; your task is to select the one that best describes why randomization is useful when running a controlled trial.
#
# ### Answer the question
# ### Possible Answers
# - A. To reduce bias caused by assigning to groups based on specific characteristics.
# - B. To ensure groups are comparable.
# - C. To maximize the chance of the results being normally distributed.
# - D. To reduce bias, ensure groups are comparable, and increase the chances that results will be representative of the target population.
# - E. To prevent participants from knowing whether they are in the treatment or control group
#
# Answer: D

# %% [markdown]
# # 6. Identifying correlation between variables
# ### Exercise
# You saw that adding a trendline to a scatter plot is a great way to get a sense of the strength and direction of a relationship between variables.
#
# An app has been provided for you to display scatter plots with a trendline for data about cities. The data point represents a city, and its location in the plot is determined by the cost of a bottle of water and a monthly gym membership in that city.
#
# Your task is to describe the Pearson correlation coefficient for the cost of a bottle of water (£) as the dependent variable and annual hours worked as the independent variable.
#
# ### Instruction
# - A. Weak-to-moderate positive relationship
# - B. Strong negative relationship
# - C. Weak-to-moderate negative relationship
# - D. Weak positive relationship
#
# Answer: C

# %% [markdown]
# # 7. What can correlation tell you?
# ### Exercise
# In the last exercise, you saw a weak-to-moderate negative relationship between the cost of a bottle of water and the number of hours worked annually in different cities. Here is the plot as a reminder:
#
# ![](ch4_ex10.png)
#
# Your task is to choose the statement that accurately describes what you can reasonably conclude from this visualization.
#
# ### Answer the question
# ### Possible Answers
#
# - A. An increase in the number of hours worked annually causes a decrease in the cost of a bottle of water.
# - B. An increase in the number of hours worked annually is related to an increase in the cost of a bottle of water.
# - C. A decrease in the cost of a bottle of water causes a decrease in the number of hours worked annually.
# - D. An increase in the number of hours worked annually is related to a decrease in the cost of a bottle of water.
#
# Answer: D

# %% [markdown]
# # 8. Confounding variables
# ### Exercise
# You have been asked to perform an experiment to investigate the relationship between neighborhood residence and lung capacity. You will measure the lung capacity of thirty people from neighborhood A, which is located near a highway, and thirty people from neighborhood B, which is not near a highway. Both groups have similar smoking habits and a similar gender breakdown.
#
# Which of the following could be a confounding variable in this experiment?
#
# ### Answer the question
# ### Possible Answers
# - A. Lung capacity
# - B. Neighborhood
# - C. Air pollution
# - D. Smoking status
# - E. Gender
#
# Answer: C

# %% [markdown]
# # 9.Significance levels vs. p-values
# ### Exercise
# You learned about two very important elements of hypothesis testing: significance levels () and p-values.
#
# It is very common to get these two confused, especially when you are new to statistics!
#
# In this exercise, you have been provided with statements and need to match the definitions provided based on whether they accurately describe  or p-values.
#
# ### Instruction
# Match the statements to the correct bucket.
#
# ### Drag the items into the correct bucket:
# - This metric is calculated after data has been colected.
# - This describes the probability of obtaining results at least as extreme as those observed.
# - Also known as alpha.
# - This is a threshold assigned to represent the probability of falsely rejecting the null hypothesis.
# - To reject the null hypothesis this value must be less than or equal to alpha.
# - This is set before data collection.
#
# ### Answers:
# Significance level:
# - Also known as alpha.
# - This is a threshold assigned to represent the probability of falsely rejecting the null hypothesis.
# - This is set before data collection.
#
# p-value:
# - This metric is calculated after data has been colected.
# - This describes the probability of obtaining results at least as extreme as those observed.
# - To reject the null hypothesis this value must be less than or equal to alpha.

# %% [markdown]
# # 10. Type I and type II errors
# ### Exercise
# You are interested in whether there is a difference in average weight between adult men in Madrid, Spain, and Berlin, Germany.
#
# Your null hypothesis is that there is no difference in weight between men in Madrid and Berlin, and your alternative hypothesis is that men in Berlin are heavier than those in Madrid.
#
#  has been set to 0.05, and the weights of 100 adult male residents from each city have been collected. Sampling with replacement has been performed to produce 10000 sample means of both cities. What conclusion can you draw based on the sample mean distributions?
#
# ![](ch4_ex13.png)
#
# ### Answer the question
# ### Possible Answers
# - A.Reject the null hypothesis, men in Berlin are heavier than men in Madrid
# press
# 1
#
# Accept the null hypothesis, there is no difference between men's weight in Berlin and Madrid
# press
# 2
#
# It is impossible to determine this from the plot
# press
# 3
#
# Reject the null hypothesis, men in Madrid are heavier than men in Berlin
