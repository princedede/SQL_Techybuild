# %% [markdown]
# # 1. Recognizing a binomial distribution
# ### Exercise
# Recall that a binomial distribution counts the number of successes in independent events.
#
# Four scenarios are provided below; your task is to choose which one describes a binomial distribution based on the type of data described.
#
# ### Answer the question
# ### Possible Answers
# - A. The probability of a train arriving in under 10 minutes.
# - B. The probability of a man's height being 175 centimeters or less.
# - C. The probability of matching four numbers in the lottery.
# - D. The probability of the temperature being more than 80 degrees Celsius.
#
# Answer: C

# %% [markdown]
# # 2. How probability affects the binomial distribution
# ### Exercise
# Recall that the binomial distribution can be described by two parameters,  and .
#
# To examine how these parameters affect the distribution, three plots have been provided representing the probability of closing between one and 12 sales per week for three sales people. The probability, , is different for each individual.
#
# Your task is to select which sales person has the highest probability of closing nine or more sales per week.
#
# ![](ch3_ex2_v2.png)
#
# ### Answer the question
# ### Possible Answers
# - A. George
# - B. Izzy
# - C. James
#
# Answer: C

# %% [markdown]
# # 3. Identifying n and p
# Great work recognizing which sales person had the highest probability of closing nine or more sales.
#
# Recall that the shape of a binomial distribution is determined by the parameters  and , and the expected value is represented by the bar with the highest peak.
#
# But can you spot what n and p are for James' sales distribution?
#
# ![](james_sales_distribution.png)
#
# ### Answer the question
# ### Possible Answers
# - A. n = 8, p = 12
# - B. n = 12, p = 0.23
# - C. n = 8, p = 0.23
# - D. n = 12, p = 0.67
#
# Answer: D

# %% [markdown]
# # 4. Recognizing the normal distribution
# ### Exercise
# The normal distribution is commonly observed in the real-world, such as shoe size, adult height, birth weight of babies, and IQ scores; therefore, it is important to be able to recognize this distribution when visualizing data.
#
# Here is a grid of four plots displaying the distribution of schools achieving various percentages of pass grades for secondary school exams in the United Kingdom, where each visualization represents students from a different ethnicity.
#
# Your task is to identify which of these plots does not represent a normal distribution.
#
# ![](ch3_ex5.png)
#
# ### Answer the question
# ### Possible Answers
# - A. Plot A
# - B. Plot B
# - C. Plot C
# - D. Plot D
#
# Answer: C

# %% [markdown]
# # 5. What makes the normal distribution special?
# ### Exercise
# In the video, you learned several special facts about the normal distribution.
#
# Your task in this exercise is to classify which of these facts are unique to the normal distribution and which apply to all probability distributions.
#
# ### Instruction
# Classify each fact as either being specific to the normal distribution or applicable to any probability distribution.
#
# ### Drag the items into the correct bucket:
# - The total area of the distribution equals one
# - Described by the mean and standard deviation
# - Probabilities of specific events occurring can be calculated using the area under the curve
# - Symmetrical
# - Required for many statistical tests to be performed
# - Displays the probability of possible outcomes for numeric values
#
# ### Answers:
# Normal distribution:
# - Described by the mean and standard deviation
# - Symmetrical
# - Required for many statistical tests to be performed
#
# All distributions:
# - The total area of the distribution equals one
# - Probabilities of specific events occurring can be calculated using the area under the curve
# - Displays the probability of possible outcomes for numeric values

# %% [markdown]
# # 6. Identifying skewness
# ### Exercise
# While the normal distribution is commonly observed in the real-world, it is also quite likely that you will encounter data that is skewed.
#
# Recognizing the direction of the skew and what this means for the data you are interpreting is an extremely valuable skill!
#
# Two distributions have been provided. Each statement describes either the direction of skewness for one of the two distributions, or an interpretation of the data based on its distribution.
#
# Your task is to classify whether the following statements are true or false.
#
# ![](ch3_ex7.png)
#
# ### Instruction
# Classify each statement as true or false.
#
# ### Drag the items into the correct bucket:
# - A large number of schools achieve 100% pass grades among their students.
# - A small nuimber of schools have over 6000 students.
# - The distribution of School Pass Grades is left-skewed.
# - Distribution of School Size is left-skewed.
# - The distribution of School Pass Grades is right-skewed.
# - The majority of schools have less than 50% of their students achieving pass grades.
# - The majority of schools have over 4000 students.
# - Distribution of School Size is right-skewed.
#
# ### Answer:
# True:
# - A large number of schools achieve 100% pass grades among their students.
# - A small nuimber of schools have over 6000 students.
# - The distribution of School Pass Grades is left-skewed.
# - Distribution of School Size is right-skewed.
#
# False:
# - Distribution of School Size is left-skewed.
# - The distribution of School Pass Grades is right-skewed.
# - The majority of schools have less than 50% of their students achieving pass grades.
# - The majority of schools have over 4000 students.

# %% [markdown]
# # 7. Describing distributions using kurtosis
# ### Exercise
# Another means of describing the shape of a distribution is by its kurtosis, which can represent the size of its central peak and how spread out the tails are.
#
# Kurtosis allows you to summarize whether values are bunched up close to the mean, and how far out any extreme values may lie.
#
# Three definitions have been provided. Your task is to select which one accurately represents a normal distribution with negative kurtosis.
#
# ### Answer the question
# ### Possible Answers
#
# - A. A distribution with the same kurtosis as a normal distribution.
# - B. A distribution with a larger central peak and smaller tails compared to a typical normal distribution.
# - C. A distribution with a smaller peak and wider tails compared to a typical normal distribution.
#
# Answer: C

# %% [markdown]
# # 8. Visualizing sampling distributions
# ### Exercise
# Now let's check your understanding of how the central limit theorem applies to different distributions!
#
# An app has been displayed allowing you to create sampling distributions of different summary statistics from samples of different distributions.
#
# Which distribution does the central limit theorem apply to?
#
# ### Instruction
# - A. Discrete uniform distribution
# - B. Continuous uniform distribution
# - C. Binomial distribution
# - D. All of the above
#
# Answer: D

# %% [markdown]
# # 9. The CLT vs. The law of large numbers
# ### Exercise
# Recall that earlier in the course you learned about the law of large numbers. As a reminder, here is a plot showing the distribution of 100 samples and 1000 samples of a die roll.
#
# ![](law_of_large_numbers_ch3.png)
#
# This concept can sometimes be confused with the central limit theorem, so let's check your understanding of the definitions and differences between the two.
#
# You will need to classify each statement as being applicable to either the central limit theorem or the law of large numbers.
#
# ### Instruction
# Match the statement to the correct concept.
#
# ### Drag the items into the correct bucket:
# - This concept generally applies once the sample size is 30 or more.
# - This concept does not always result in a sample taking the form of a normal distribution as sample size increases.
# - As the number of sample summary statistics calculated increases, the distribution will more closely resemble a normal distribution.
# - As the sample increases, the sample mean gets closer to the value of the population mean.
#
# ### Answers:
# The law of large numbers:
# - This concept does not always result in a sample taking the form of a normal distribution as sample size increases.
# - As the sample increases, the sample mean gets closer to the value of the population mean.
#
# The central limit theorem:
# - This concept generally applies once the sample size is 30 or more.
# - As the number of sample summary statistics calculated increases, the distribution will more closely resemble a normal distribution.

# %% [markdown]
# # 10. When to use the central limit theorem
# ### Exercise
# In the video, you saw a workflow on whether the central limit theorem should be applied or not, depending on various factors.
#
# In this exercise, four scenarios have been provided. Your task is to choose which scenario would require the use of the central limit theorem to produce summary statistics that are normally distributed.
#
# ### Answer the question
# ### Possible Answers
# - A. Finding the mean IQ of all 100 students in a high school.
# - B. Measuring the standard deviation of household income in a road with 20 houses.
# - C. Determining the percentage of adults in the USA that have been diagnosed with Type 2 Diabetes.
# - D. Counting the number of babies born with blue eyes in a hospital within one day.
#
# Answer: C

# %% [markdown]
# # 11. Identifying Poisson processes
# ### Exercise
# The Poisson distribution is very important because it occurs in a variety of real-life circumstances. Recognizing when the Poisson distribution applies can be helpful for business planning or in studying the occurrence of events in nature!
#
# Your task in this exercise is to match the scenarios provided to either the Poisson distribution or another distribution.
#
# ### Instruction
# Match the scenarios to the appropriate distribution.
#
# ### Drag the items into the correct bucket:
# - Number of earthquakes in the state of California in a year.
# - Probability of voting for a political candidate.
# - Number of books sold per week.
# - Number of side effects from a range of medications.
# - Probability of a mobile phone being broken.
# - Volume of mortgage applications received per month.
#
# ### Answers:
# Poisson distribution:
# - Number of earthquakes in the state of California in a year.
# - Number of books sold per week.
# - Volume of mortgage applications received per month.
#
# Other distribution:
# - Probability of voting for a political candidate.
# - Number of side effects from a range of medications.
# - Probability of a mobile phone being broken.

# %% [markdown]
# # 12. Recognizing lambda in the Poisson distribution
# Now that you've learned about the Poisson distribution, you know that its shape is described by a value called lambda ($\lambda$). In this exercise, you'll select which of these plots represents a Poisson distribution with lambda equal to two.
#
# ![](ch3_ex13.png)
#
# ### Answer the question
# ### Possible Answers
# - A. A
# - B. B
# - C. C
#
# Answer: B
